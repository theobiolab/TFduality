# %%
import numpy as np
import sys, os
sys.path.append('../../shared/utilsGRF/')
from IPython.display import display
import writescripts

# %%
edges=[(1,'a1',2),(2,'a1r',1),(2,'a2',3),(3,'a3',4),(4,'a4',1),
       (5,'alpha1',6),(6,'alpha1r',5),(6,'alpha2',7),(7,'alpha3',8),(8,'alpha4',5),
      (1,'kb1-x',5),(5,'ku1',1),(2,'kb2-x',6),(6,'ku2',2),(3,'kb3-x',7),(7,'ku3',3),(4,'kb4-x',8),(8,'ku4',4)]

MTTfolder='../../shared/utilsGRF' #folder with MTT.py 
basename='graph'

parlist=[x[1] for x in edges]
parlist=list(set(parlist))


list(set(parlist))

for pnum,par in enumerate(parlist):
    if '-x' in par:
        parlist[pnum]=parlist[pnum].replace('-x','')
print(parlist)

obj=writescripts.PrepareFilesNoneq(edgelist=edges,varGRF='x',concvars=['x'],parlist=parlist,MTTfolder=MTTfolder,graphbasename=basename)
obj.write_execute_parse()

obj.simpify_rhos()
# Out:
# ['a3', 'kb1', 'ku1', 'alpha1', 'a4', 'kb3', 'kb2', 'alpha2', 'kb4', 'alpha1r', 'a1r', 'ku4', 'ku2', 'alpha3', 'a1', 'ku3', 'alpha4', 'a2']
# removing  ../../shared/utilsGRF/graph-parsed.txt
# removing  ../../shared/utilsGRF/graph-6.txt
# removing  ../../shared/utilsGRF/graph-7.txt
# removing  ../../shared/utilsGRF/graph-5.txt
# removing  ../../shared/utilsGRF/graph-4.txt
# removing  ../../shared/utilsGRF/graph-1.txt
# removing  ../../shared/utilsGRF/graph-3.txt
# removing  ../../shared/utilsGRF/graph-2.txt
# removing  ../../shared/utilsGRF/graph-8.txt
# removing  ../../shared/utilsGRF/graph.txt
# executing MTT
# 0

# %%
import sympy
from sympy.parsing.sympy_parser import parse_expr

# %%
sympy.init_printing()

# %%
for label in parlist:
    #print(label)
    exec("%s=sympy.symbols('%s')"%(label,label))
for var in ['x']:
    exec("%s=sympy.symbols('%s')"%(var,var))
epsilon1,epsilon2,epsilon3,epsilon1r,epsilon4,kb,ku=sympy.symbols('epsilon_1,epsilon_2,epsilon_3,epsilon1r,epsilon4,k_b,k_u')
all_rhos_sympy=[]
for rho in obj.all_rhos:
    expr=parse_expr(rho.split("=")[1])
    expr_simple=expr.subs({alpha1:epsilon1*a1,alpha1r:epsilon1r*a1r,alpha2:epsilon2*a2,alpha3:epsilon3*a3,alpha4:epsilon4*a4,kb1:kb,kb2:kb,kb3:kb,kb4:kb,ku1:ku,ku2:ku,ku3:ku,ku4:ku})
    all_rhos_sympy.append(expr_simple)

# %%
for i in range(6):
    print("Trees for node ",i+1)
    for tree in sympy.Add.make_args(all_rhos_sympy[i]):
        print(tree)
    print()
# Out:
# Trees for node  1
# a1r*a3*a4*k_u**4
# a2*a3*a4*k_u**4
# a1r*a3*a4**2*epsilon4*k_u**3
# a1r*a3**2*a4*epsilon_3*k_u**3
# a2*a3*a4**2*epsilon4*k_u**3
# a2*a3**2*a4*epsilon_3*k_u**3
# a1r**2*a3*a4*epsilon1r*k_u**3
# a2**2*a3*a4*epsilon_2*k_u**3
# a1*a1r*a3*a4*epsilon_1*k_u**3
# a1*a2*a3*a4*epsilon_1*k_u**3
# a1r*a2*a3*a4*epsilon1r*k_u**3
# a1r*a2*a3*a4*epsilon_2*k_u**3
# a1r*a3**2*a4**2*epsilon4*epsilon_3*k_u**2
# a2*a3**2*a4**2*epsilon4*epsilon_3*k_u**2
# a1r**2*a3*a4**2*epsilon1r*epsilon4*k_u**2
# a2**2*a3*a4**2*epsilon4*epsilon_2*k_u**2
# a1r**2*a3**2*a4*epsilon1r*epsilon_3*k_u**2
# a2**2*a3**2*a4*epsilon_2*epsilon_3*k_u**2
# a1*a1r*a3*a4**2*epsilon4*epsilon_1*k_u**2
# a1*a1r*a3**2*a4*epsilon_1*epsilon_3*k_u**2
# a1*a2*a3*a4**2*epsilon4*epsilon_1*k_u**2
# a1*a2*a3**2*a4*epsilon_1*epsilon_3*k_u**2
# a1*a2**2*a3*a4*epsilon_1*epsilon_2*k_u**2
# a1r*a2*a3*a4**2*epsilon1r*epsilon4*k_u**2
# a1r*a2*a3*a4**2*epsilon4*epsilon_2*k_u**2
# a1r*a2*a3**2*a4*epsilon1r*epsilon_3*k_u**2
# ...

# %%
phi1=all_rhos_sympy[0]
phi2=all_rhos_sympy[1]
phi3=all_rhos_sympy[2]
phi4=all_rhos_sympy[3]
phi5=all_rhos_sympy[4]
phi6=all_rhos_sympy[5]
phi7=all_rhos_sympy[6]
phi8=all_rhos_sympy[7]

# %%
phi1+phi2+phi3
# Out:
#   2   2                       2   2   2                 2   2
# a₁ ⋅a₂ ⋅a₃⋅a₄⋅ε₁⋅ε₂⋅ε₃⋅kᵤ + a₁ ⋅a₂ ⋅a₄ ⋅ε₄⋅ε₁⋅ε₂⋅kᵤ + a₁ ⋅a₂ ⋅a₄⋅ε₄⋅ε₁⋅ε₂⋅k_b⋅
#
#          2   2            2     2      2                    2         2
# kᵤ⋅x + a₁ ⋅a₂ ⋅a₄⋅ε₁⋅ε₂⋅kᵤ  + a₁ ⋅a₂⋅a₃ ⋅a₄⋅ε₁⋅ε₂⋅ε₃⋅kᵤ + a₁ ⋅a₂⋅a₃⋅a₄ ⋅ε₄⋅ε₁⋅
#
#           2         2                 2                                2
# ε₂⋅kᵤ + a₁ ⋅a₂⋅a₃⋅a₄ ⋅ε₄⋅ε₁⋅ε₃⋅kᵤ + a₁ ⋅a₂⋅a₃⋅a₄⋅ε₄⋅ε₁⋅ε₃⋅k_b⋅kᵤ⋅x + a₁ ⋅a₂⋅a₃
#
#                           2                  2     2                  2     2
# ⋅a₄⋅ε₁⋅ε₂⋅ε₃⋅k_b⋅kᵤ⋅x + a₁ ⋅a₂⋅a₃⋅a₄⋅ε₁⋅ε₂⋅kᵤ  + a₁ ⋅a₂⋅a₃⋅a₄⋅ε₁⋅ε₃⋅kᵤ  + a₁ ⋅
#
#      2                       2      2         2     2                   2
# a₂⋅a₄ ⋅ε₄⋅ε₁⋅ε₂⋅k_b⋅kᵤ⋅x + a₁ ⋅a₂⋅a₄ ⋅ε₄⋅ε₁⋅kᵤ  + a₁ ⋅a₂⋅a₄⋅ε₄⋅ε₁⋅ε₂⋅k_b ⋅kᵤ⋅x
#
# 2     2                   2       2                   2       2            3
#   + a₁ ⋅a₂⋅a₄⋅ε₄⋅ε₁⋅k_b⋅kᵤ ⋅x + a₁ ⋅a₂⋅a₄⋅ε₁⋅ε₂⋅k_b⋅kᵤ ⋅x + a₁ ⋅a₂⋅a₄⋅ε₁⋅kᵤ  +
#
# ...

# %%
phi4+phi5+phi6
# Out:
#   2   2   2                 2   2                       2   2
# a₁ ⋅a₂ ⋅a₃ ⋅ε₁⋅ε₂⋅ε₃⋅kᵤ + a₁ ⋅a₂ ⋅a₃⋅a₄⋅ε₄⋅ε₁⋅ε₂⋅kᵤ + a₁ ⋅a₂ ⋅a₃⋅ε₁⋅ε₂⋅ε₃⋅k_b⋅
#
#          2   2            2     2      2                       2      2
# kᵤ⋅x + a₁ ⋅a₂ ⋅a₃⋅ε₁⋅ε₂⋅kᵤ  + a₁ ⋅a₂⋅a₃ ⋅a₄⋅ε₄⋅ε₁⋅ε₃⋅k_b⋅x + a₁ ⋅a₂⋅a₃ ⋅a₄⋅ε₄⋅
#
#              2      2                       2      2         2     2         2
# ε₁⋅ε₃⋅kᵤ + a₁ ⋅a₂⋅a₃ ⋅ε₁⋅ε₂⋅ε₃⋅k_b⋅kᵤ⋅x + a₁ ⋅a₂⋅a₃ ⋅ε₁⋅ε₃⋅kᵤ  + a₁ ⋅a₂⋅a₃⋅a₄
#
#                     2                                2                      2
# ⋅ε₄⋅ε₁⋅ε₃⋅k_b⋅x + a₁ ⋅a₂⋅a₃⋅a₄⋅ε₄⋅ε₁⋅ε₂⋅k_b⋅kᵤ⋅x + a₁ ⋅a₂⋅a₃⋅a₄⋅ε₄⋅ε₁⋅ε₃⋅k_b ⋅
#
#  2     2                             2                  2     2
# x  + a₁ ⋅a₂⋅a₃⋅a₄⋅ε₄⋅ε₁⋅k_b⋅kᵤ⋅x + a₁ ⋅a₂⋅a₃⋅a₄⋅ε₄⋅ε₁⋅kᵤ  + a₁ ⋅a₂⋅a₃⋅ε₁⋅ε₂⋅ε₃
#
#     2     2     2                   2       2                   2       2
# ⋅k_b ⋅kᵤ⋅x  + a₁ ⋅a₂⋅a₃⋅ε₁⋅ε₂⋅k_b⋅kᵤ ⋅x + a₁ ⋅a₂⋅a₃⋅ε₁⋅ε₃⋅k_b⋅kᵤ ⋅x + a₁ ⋅a₂⋅a
#
# ...

# %%
num=a4*phi4+a4*epsilon4*phi8
den=phi1+phi2+phi3+phi4+phi5+phi6+phi7+phi8

# %%
dnum=sympy.diff(num,x)
dden=sympy.diff(den,x)

# %%
#left=(sympy.diff(phi3,ku)+alpha3*sympy.diff(phi6,ku))*den
#right=(phi3+alpha3*phi6)*dden
left=dnum*den
right=num*dden

# %%
#B=sympy.symbols('B')

# %%
l_r=sympy.expand(left-right)
#l_rB=l_r.subs(kb*x,B)
poly_zero=sympy.Poly(l_r,x)

# %%
poly_zero.degree()
# Out:
# 6

# %%
from sympy.printing import mathematica

# %%
math_output=open("tocheckwithm_nonmx_4steps_rev.in","w")
all_terms=[]
for cn,coeff in enumerate(poly_zero.coeffs()[::-1]):
    termsc=[]
    print(cn)
    for monomial in sympy.Add.make_args(coeff):
        #print(monomial, sympy.Mul.make_args(monomial))
        noneps=[]
        eps=[]
        number=1
        eps_base=[] #bases, for ordering by letter
        noneps_base=[] #bases, for ordering by letter
        args= sympy.Mul.make_args(monomial) #separate each monomial into each variable (a,epsilon,number)
        for arg_ in args:
            if type(arg_)==sympy.power.Pow:
                arg=sympy.power.Pow.as_base_exp(arg_)[0] #get the base of the power so that I can check if it is epsilon or not
            else:
                arg=arg_
            if  arg in [epsilon1,epsilon2,epsilon3,epsilon1r,epsilon4]:
                eps.append(arg_)
                eps_base.append(arg.name)
            else:
                
                #print(type(arg))
                if type(arg)!=sympy.numbers.Integer and type(arg)!=sympy.numbers.NegativeOne:
                    noneps_base.append(arg.name)
                    noneps.append(arg_)
                else:
                    number=arg
                    
        #print(monomial)
        #print(number)
        noneps_o=np.array(noneps)[np.argsort(np.array(noneps_base))]
        eps_o=np.array(eps)[np.argsort(np.array(eps_base))]
        #print(number,noneps_o,eps_o)
        termsc.append([number,noneps_o,eps_o])
    all_terms.append(termsc)

for i in range(len(all_terms)):
    print("degree ",i)
    coeffi=all_terms[i]
    #print(coeffi)
    base=[] #list of common factors that do not contain epsilons
    #find the unique common factors without epsilons
    for j in range(len(coeffi)):
        b=coeffi[j][1]
        present=False
        for k in range(len(base)):
            if np.all(base[k]==b):
                present=True
        if not present:
            base.append(b)
    #find which term in the original coefficient expression correspond to each common factor
    common_bases_idx=[[] for i in range(len(base))] #which terms have those common factors
    for j in range(len(coeffi)):
        b=coeffi[j][1]
        for k in range(len(base)):
            if np.all(base[k]==b):
                common_bases_idx[k].append(j)
    #now for each base, print the epsilon terms side by side to check which sign wins 
    print(len(base))
    for k in range(len(base)):
        #print(base[k])
        idxs=common_bases_idx[k]
        epsilons_terms=0
        for idx in idxs:
            terms=coeffi[idx]
            #print(terms)
            number=terms[0]
            epsilons=terms[2]
            prod=1
            for e in epsilons:
                prod*=e

            #if np.abs(number)==1:
            epsilons_terms+=number*prod
            #else:
            #    if number<1:
            #        sign=-1
            #    else:
            #        sign=1
            #    for k in range(np.abs(number)):
            #        epsilons_terms+=sign*prod
        #display(epsilons_terms)
        #display(idx,sympy.factor(epsilons_terms),epsilons_terms)
        math_output.write(str(i)+";"+mathematica.mathematica_code(epsilons_terms).replace("_","")+"\n")
math_output.close()
        
#print(base)
#print(common_bases_idx)
    
        
#then identify together those with same noneps
#common together epsilons with the number (Integer)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# degree  0
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:49: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# 324
# degree  1
# 289
# degree  2
# 230
# degree  3
# 150
# degree  4
# 76
# degree  5
# 25
# degree  6
# 5

# %%
4+4+2+8+8-6-6-2-3-2-4-1-1-1
# Out:
# 0

# %% [markdown]
# Timeouts:

# %%
228:(= indicates doublechecked)
-4 epsilon1r epsilon2 epsilon3=
+2 epsilon1^2 epsilon2 epsilon3=
+epsilon1 epsilon2^2 epsilon3=
+epsilon1r epsilon2 epsilon3 epsilon4=


-4 epsilon1 epsilon1r epsilon3=
+4 epsilon1^2 epsilon2 epsilon3=



-8 epsilon1r epsilon3 epsilon4=
+4 epsilon1r epsilon3 epsilon4^2=
+2 epsilon1 epsilon1r epsilon3 epsilon4=
+2 epsilon1r epsilon3^2 epsilon4=

-8 epsilon1 epsilon2 epsilon3=
+5 epsilon1 epsilon2^2 epsilon3=
+3 epsilon1 epsilon2 epsilon3 epsilon4=


-2 epsilon1r epsilon3^2=
+epsilon1 epsilon2 epsilon3^2=
+epsilon1r epsilon2 epsilon3^2=

# %%
230:
-2 epsilon1^2 epsilon2=
+2 epsilon1^2 epsilon2^2=

-4 epsilon1 epsilon1r epsilon3=
+epsilon1 epsilon1r epsilon2 epsilon3=
+1 epsilon1 epsilon1r epsilon3 epsilon4=
+2 epsilon1 epsilon1r epsilon3^2=


-2 epsilon1 epsilon1r epsilon2=
+epsilon1^2 epsilon2 epsilon4=
+epsilon1^2 epsilon2 epsilon3=

-4 epsilon1 epsilon1r epsilon4=
+2 epsilon1 epsilon1r epsilon4^2=
+epsilon1 epsilon1r epsilon2 epsilon4=
+1 epsilon1 epsilon1r epsilon3 epsilon4=

# %%
520 timeout2 as well: 
    
-4 epsilon1 epsilon1r epsilon2=
+2 epsilon1^2 epsilon2^2=
+2 epsilon1 epsilon1r epsilon2 epsilon3=

-8 epsilon1 epsilon1r epsilon3=
+2 epsilon1 epsilon1r epsilon3^2=
+6 epsilon1^2 epsilon2 epsilon3=

-6 epsilon1r epsilon2 epsilon3=
+2 epsilon1r epsilon2 epsilon3^2=
+4 epsilon1 epsilon2^2 epsilon3=

-6 epsilon1 epsilon1r epsilon4=
+2 epsilon1 epsilon1r epsilon2 epsilon4=
+2 epsilon1 epsilon1r epsilon4^2=
+2 epsilon1 epsilon2 epsilon4^2=

-8 epsilon1r epsilon2 epsilon4=
+2 epsilon1r epsilon2 epsilon4^2=
+4 epsilon1r epsilon2 epsilon3 epsilon4=
+2 epsilon1^2 epsilon2 epsilon4=

-12 epsilon1r epsilon3 epsilon4=
+4 epsilon1 epsilon1r epsilon3 epsilon4=
+4 epsilon1r epsilon3^2 epsilon4=
+4 epsilon1r epsilon3 epsilon4^2=

-10 epsilon1 epsilon2 epsilon3=
+6 epsilon1 epsilon2 epsilon3 epsilon4=
+2 epsilon1 epsilon2 epsilon3^2=
+2 epsilon1 epsilon2^2 epsilon3=

-10 epsilon1 epsilon2 epsilon4=
+4 epsilon1^2 epsilon2 epsilon4=
+6 epsilon1 epsilon2^2 epsilon4+=

# %%
524 timeout2 as well: 


-6 epsilon1 epsilon1r epsilon3^2=
+6 epsilon1 epsilon2^2 epsilon3^2=

-8 epsilon1 epsilon2 epsilon3^2=
+6 epsilon1^2 epsilon2 epsilon3^2=
+2 epsilon1 epsilon2 epsilon3^2 epsilon4=



-4 epsilon1r epsilon2 epsilon3^2=
+2 epsilon1 epsilon1r epsilon2 epsilon3^2=
+2 epsilon1r epsilon2 epsilon3^2 epsilon4=


-18 epsilon1 epsilon2 epsilon3 epsilon4=
+12 epsilon1^2 epsilon2 epsilon3 epsilon4=
+4 epsilon1 epsilon2^2 epsilon3 epsilon4=
+2 epsilon1 epsilon2 epsilon3 epsilon4^2=

-8 epsilon1r epsilon3^2 epsilon4=
+4 epsilon1 epsilon1r epsilon3^2 epsilon4=
+4 epsilon1r epsilon3^2 epsilon4^2=

-8 epsilon1 epsilon1r epsilon2 epsilon3=
+4 epsilon1^2 epsilon2^2 epsilon3=
+4 epsilon1 epsilon2 epsilon3^2 epsilon4=


-12 epsilon1 epsilon1r epsilon3 epsilon4=
+6 epsilon1 epsilon1r epsilon2 epsilon3 epsilon4=
+4 epsilon1 epsilon1r epsilon3 epsilon4^2=
+2 epsilon1 epsilon2 epsilon3 epsilon4^2=

-14 epsilon1r epsilon2 epsilon3 epsilon4=
+8 epsilon1 epsilon2^2 epsilon3 epsilon4=
+4 epsilon1r epsilon2 epsilon3 epsilon4^2=
+2 epsilon1r epsilon2 epsilon3^2 epsilon4=

# %%
701 timeout2 as well: 
    
-8 epsilon1r^2 epsilon3 epsilon4=
+8 epsilon1 epsilon1r epsilon2 epsilon3 epsilon4=

-2 epsilon1r^2 epsilon3^2 epsilon4=
+2 epsilon1 epsilon2 epsilon3^2 epsilon4=

-4 epsilon1r epsilon3^2 epsilon4=
+2 epsilon1 epsilon1r epsilon3^2 epsilon4=
+2 epsilon1r epsilon2 epsilon3^2 epsilon4=


-4 epsilon1r^2 epsilon4^2=
+4 epsilon1 epsilon1r epsilon2 epsilon4^2=

-4 epsilon1r^2 epsilon3 epsilon4^2=
+4 epsilon1r epsilon2 epsilon3 epsilon4^2=

-8 epsilon1r epsilon3 epsilon4^2=
+4 epsilon1 epsilon1r epsilon3 epsilon4^2=
+4 epsilon1 epsilon2 epsilon3 epsilon4^2=

# %%
+2 epsilon1r epsilon3^2 epsilon4^2

# %%
776 timeout2 as well: 
    
-3 epsilon1^2 epsilon2 epsilon3=
+3 epsilon1^2 epsilon2^2 epsilon3=

-2 epsilon1^2 epsilon2 epsilon4=
+1 epsilon1^2 epsilon2^2 epsilon4=
+1 epsilon1^2 epsilon2 epsilon4^2=

-2 epsilon1 epsilon2^2 epsilon3=
+1 epsilon1^2 epsilon2^2 epsilon3=
+1 epsilon1 epsilon2^2 epsilon3^2=

-2 epsilon1 epsilon1r epsilon3^2=
+2 epsilon1 epsilon2^2 epsilon3^2=

-3 epsilon1 epsilon2 epsilon4^2=
+3 epsilon1 epsilon2^2 epsilon4^2=

-2 epsilon1r epsilon2 epsilon4^2=
+2 epsilon1^2 epsilon2 epsilon4^2=

-2 epsilon1r epsilon3 epsilon4^2=
+2 epsilon1r epsilon3^2 epsilon4^2=

-epsilon1 epsilon1r epsilon4^2=
+1 epsilon1 epsilon2^2 epsilon4^2=


-9 epsilon1 epsilon1r epsilon2 epsilon3=
+3 epsilon1 epsilon1r epsilon2 epsilon3^2=
+5 epsilon1^2 epsilon2 epsilon3 epsilon4=
+1 epsilon1^2 epsilon2 epsilon3^2=


-epsilon1r epsilon2 epsilon3^2=
+1 epsilon1r epsilon2 epsilon3^2 epsilon4=


-3 epsilon1 epsilon2 epsilon3^2=
+3 epsilon1^2 epsilon2 epsilon3^2=


-2 epsilon1r epsilon3^2 epsilon4=
+1 epsilon1 epsilon1r epsilon3^2 epsilon4=
+1 epsilon1r epsilon2 epsilon3^2 epsilon4=

-9 epsilon1 epsilon1r epsilon2 epsilon4=
+3 epsilon1 epsilon1r epsilon2 epsilon4^2=
+4 epsilon1 epsilon2^2 epsilon3 epsilon4=
+2 epsilon1 epsilon1r epsilon2 epsilon3 epsilon4=

-3 epsilon1 epsilon2^2 epsilon4=
+3 epsilon1^2 epsilon2^2 epsilon4=

-16 epsilon1 epsilon1r epsilon3 epsilon4=
+8 epsilon1 epsilon1r epsilon2 epsilon3 epsilon4=
+4 epsilon1 epsilon1r epsilon3 epsilon4^2=
+4 epsilon1 epsilon1r epsilon3^2 epsilon4=

-20 epsilon1 epsilon2 epsilon3 epsilon4=
+5 epsilon1 epsilon2 epsilon3^2 epsilon4=
+5 epsilon1 epsilon2 epsilon3 epsilon4^2=
+10 epsilon1 epsilon2^2 epsilon3 epsilon4=

-16 epsilon1r epsilon2 epsilon3 epsilon4=
+9 epsilon1^2 epsilon2 epsilon3 epsilon4=
+2 epsilon1r epsilon2 epsilon3 epsilon4^2=
+2 epsilon1r epsilon2 epsilon3^2 epsilon4=
+3 epsilon1r epsilon2 epsilon3 epsilon4^2=
